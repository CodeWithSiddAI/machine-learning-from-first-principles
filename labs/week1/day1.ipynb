# %%
import numpy as np

# Features [house size, no.of bedroom]
X = np.array([
    [1200, 2],
    [1800, 3],
    [2400, 4]
])

# Target (house prices)
y = np.array([45, 72, 105])

print('Features:')
print(X)

print('Target:')
print(y)
# Out:
# Features:
# [[1200    2]
#  [1800    3]
#  [2400    4]]
# Target:
# [ 45  72 105]
